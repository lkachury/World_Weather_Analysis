# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data
# Generate a set of 2,000 random latitudes and longitudes, retrieve the nearest city using the citipy module, and perform an API call with the OpenWeatherMap. Retrieve the following information from the API call [Latitude and longitude, maximum temperature, percent humidity, percent cloudiness, wind speed, and weather description (for example, clouds, fog, light rain, clear sky)] for each city. Then, create a new DataFrame containing the updated weather data and export it as a CSV file.

# %%
# Import the Pandas and NumPy dependencies
import pandas as pd
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function.
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bartica
# Processing Record 2 of Set 1 | half moon bay
# Processing Record 3 of Set 1 | langsa
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | victoria
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | maragogi
# Processing Record 9 of Set 1 | poum
# Processing Record 10 of Set 1 | katherine
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | bathsheba
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | skjervoy
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | vila
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | gwanda
# Processing Record 22 of Set 1 | pevek
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | fortuna
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | lorengau
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | bolshoy uluy
# City not found. Skipping...
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | wakkanai
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | danielskuil
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | oliver
# Processing Record 38 of Set 1 | higuey
# City not found. Skipping...
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | pangody
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | saint george
# Processing Record 46 of Set 1 | rocha
# Processing Record 47 of Set 1 | hasaki
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | sur
# Processing Record 2 of Set 2 | quatre cocos
# Processing Record 3 of Set 2 | vrangel
# Processing Record 4 of Set 2 | namatanai
# Processing Record 5 of Set 2 | cabedelo
# Processing Record 6 of Set 2 | mutoko
# Processing Record 7 of Set 2 | juegang
# Processing Record 8 of Set 2 | saint anthony
# Processing Record 9 of Set 2 | sabancuy
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | kitangari
# Processing Record 12 of Set 2 | iqaluit
# Processing Record 13 of Set 2 | lod
# Processing Record 14 of Set 2 | esperance
# Processing Record 15 of Set 2 | dudinka
# Processing Record 16 of Set 2 | kirakira
# Processing Record 17 of Set 2 | nemuro
# Processing Record 18 of Set 2 | divnogorsk
# Processing Record 19 of Set 2 | quelimane
# Processing Record 20 of Set 2 | gumushane
# City not found. Skipping...
# Processing Record 21 of Set 2 | calbuco
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | bubaque
# Processing Record 24 of Set 2 | tambopata
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | iberia
# Processing Record 27 of Set 2 | havoysund
# Processing Record 28 of Set 2 | mossendjo
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | nauta
# Processing Record 31 of Set 2 | verkhniy uslon
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | kahului
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | meulaboh
# Processing Record 36 of Set 2 | turan
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | nanortalik
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | erenhot
# Processing Record 42 of Set 2 | ampanihy
# Processing Record 43 of Set 2 | yar-sale
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | sitka
# Processing Record 46 of Set 2 | necochea
# Processing Record 47 of Set 2 | tokur
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | inirida
# Processing Record 50 of Set 2 | upernavik
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | ostrovnoy
# Processing Record 4 of Set 3 | cherskiy
# Processing Record 5 of Set 3 | tezu
# Processing Record 6 of Set 3 | mehamn
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | ust-kuyga
# Processing Record 9 of Set 3 | yulara
# Processing Record 10 of Set 3 | bose
# Processing Record 11 of Set 3 | pontes e lacerda
# Processing Record 12 of Set 3 | valera
# Processing Record 13 of Set 3 | japura
# Processing Record 14 of Set 3 | torbay
# Processing Record 15 of Set 3 | hopkinton
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | champerico
# Processing Record 18 of Set 3 | irtyshskiy
# Processing Record 19 of Set 3 | mantsala
# Processing Record 20 of Set 3 | kavieng
# Processing Record 21 of Set 3 | rosa zarate
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | aklavik
# Processing Record 24 of Set 3 | kondinskoye
# Processing Record 25 of Set 3 | antofagasta
# Processing Record 26 of Set 3 | alofi
# Processing Record 27 of Set 3 | innisfail
# Processing Record 28 of Set 3 | ilulissat
# Processing Record 29 of Set 3 | businga
# Processing Record 30 of Set 3 | dunedin
# Processing Record 31 of Set 3 | along
# Processing Record 32 of Set 3 | oparino
# Processing Record 33 of Set 3 | grindavik
# Processing Record 34 of Set 3 | kaitangata
# Processing Record 35 of Set 3 | kingsport
# Processing Record 36 of Set 3 | dinkelsbuhl
# Processing Record 37 of Set 3 | longyearbyen
# Processing Record 38 of Set 3 | san cristobal
# Processing Record 39 of Set 3 | pirgos
# Processing Record 40 of Set 3 | ambilobe
# Processing Record 41 of Set 3 | butaritari
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | mamakan
# Processing Record 44 of Set 3 | grand gaube
# Processing Record 45 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | clermont
# Processing Record 48 of Set 3 | grand forks
# Processing Record 49 of Set 3 | trenggalek
# Processing Record 50 of Set 3 | codrington
# Processing Record 1 of Set 4 | shimoda
# Processing Record 2 of Set 4 | namibe
# Processing Record 3 of Set 4 | kantunilkin
# Processing Record 4 of Set 4 | kaohsiung
# Processing Record 5 of Set 4 | udachnyy
# Processing Record 6 of Set 4 | agadir
# Processing Record 7 of Set 4 | beian
# Processing Record 8 of Set 4 | encruzilhada do sul
# Processing Record 9 of Set 4 | ulaangom
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | mar del plata
# Processing Record 12 of Set 4 | walvis bay
# Processing Record 13 of Set 4 | nome
# Processing Record 14 of Set 4 | saldanha
# Processing Record 15 of Set 4 | barrow
# Processing Record 16 of Set 4 | te anau
# Processing Record 17 of Set 4 | caluquembe
# Processing Record 18 of Set 4 | zhigansk
# Processing Record 19 of Set 4 | la serena
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | hithadhoo
# Processing Record 22 of Set 4 | rupert
# Processing Record 23 of Set 4 | cazaje
# City not found. Skipping...
# Processing Record 24 of Set 4 | vardo
# Processing Record 25 of Set 4 | norman wells
# Processing Record 26 of Set 4 | abu dhabi
# Processing Record 27 of Set 4 | geraldton
# Processing Record 28 of Set 4 | wenling
# Processing Record 29 of Set 4 | warrington
# Processing Record 30 of Set 4 | north platte
# Processing Record 31 of Set 4 | sinnamary
# Processing Record 32 of Set 4 | hebi
# Processing Record 33 of Set 4 | lao cai
# Processing Record 34 of Set 4 | neuquen
# Processing Record 35 of Set 4 | ndele
# Processing Record 36 of Set 4 | jutai
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | dicabisagan
# Processing Record 39 of Set 4 | san patricio
# Processing Record 40 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 4 | bonavista
# Processing Record 42 of Set 4 | berlevag
# Processing Record 43 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | sarangani
# Processing Record 46 of Set 4 | tambacounda
# Processing Record 47 of Set 4 | alyangula
# Processing Record 48 of Set 4 | natal
# Processing Record 49 of Set 4 | la grande
# Processing Record 50 of Set 4 | bulgan
# Processing Record 1 of Set 5 | balabac
# Processing Record 2 of Set 5 | vanimo
# Processing Record 3 of Set 5 | naze
# Processing Record 4 of Set 5 | hualmay
# Processing Record 5 of Set 5 | kruisfontein
# Processing Record 6 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 5 | lulea
# Processing Record 8 of Set 5 | umm lajj
# Processing Record 9 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 5 | oneida
# Processing Record 11 of Set 5 | eregli
# Processing Record 12 of Set 5 | sile
# Processing Record 13 of Set 5 | dikson
# Processing Record 14 of Set 5 | qaanaaq
# Processing Record 15 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 5 | sandakan
# Processing Record 17 of Set 5 | lompoc
# Processing Record 18 of Set 5 | biak
# Processing Record 19 of Set 5 | maceio
# Processing Record 20 of Set 5 | lebu
# Processing Record 21 of Set 5 | palana
# Processing Record 22 of Set 5 | dingle
# Processing Record 23 of Set 5 | okhotsk
# Processing Record 24 of Set 5 | rio gallegos
# Processing Record 25 of Set 5 | mirzapur
# Processing Record 26 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 5 | honiara
# Processing Record 28 of Set 5 | ahipara
# Processing Record 29 of Set 5 | rusape
# Processing Record 30 of Set 5 | khandyga
# Processing Record 31 of Set 5 | evans
# Processing Record 32 of Set 5 | lakes entrance
# Processing Record 33 of Set 5 | tuatapere
# Processing Record 34 of Set 5 | charters towers
# Processing Record 35 of Set 5 | rio grande
# Processing Record 36 of Set 5 | port blair
# Processing Record 37 of Set 5 | talnakh
# Processing Record 38 of Set 5 | mandalgovi
# Processing Record 39 of Set 5 | de-kastri
# Processing Record 40 of Set 5 | ponta do sol
# Processing Record 41 of Set 5 | hofn
# Processing Record 42 of Set 5 | porbandar
# Processing Record 43 of Set 5 | takhatpur
# Processing Record 44 of Set 5 | george town
# Processing Record 45 of Set 5 | arica
# Processing Record 46 of Set 5 | iskateley
# Processing Record 47 of Set 5 | lisa
# Processing Record 48 of Set 5 | hambantota
# Processing Record 49 of Set 5 | taltal
# Processing Record 50 of Set 5 | bethel
# Processing Record 1 of Set 6 | lima
# Processing Record 2 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 6 | nalut
# Processing Record 4 of Set 6 | chuy
# Processing Record 5 of Set 6 | sambava
# Processing Record 6 of Set 6 | malibu
# Processing Record 7 of Set 6 | faya
# Processing Record 8 of Set 6 | miandoab
# Processing Record 9 of Set 6 | cururupu
# Processing Record 10 of Set 6 | avarua
# Processing Record 11 of Set 6 | bengkulu
# Processing Record 12 of Set 6 | kavaratti
# Processing Record 13 of Set 6 | fukue
# Processing Record 14 of Set 6 | bujaru
# Processing Record 15 of Set 6 | hereford
# Processing Record 16 of Set 6 | constantine
# Processing Record 17 of Set 6 | karratha
# Processing Record 18 of Set 6 | inuvik
# Processing Record 19 of Set 6 | ratnagiri
# Processing Record 20 of Set 6 | poplar bluff
# Processing Record 21 of Set 6 | muros
# Processing Record 22 of Set 6 | kargil
# Processing Record 23 of Set 6 | pitanga
# Processing Record 24 of Set 6 | svetlyy yar
# Processing Record 25 of Set 6 | kem
# Processing Record 26 of Set 6 | sechura
# Processing Record 27 of Set 6 | lukovit
# Processing Record 28 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 29 of Set 6 | sokode
# Processing Record 30 of Set 6 | marsa matruh
# Processing Record 31 of Set 6 | asekeyevo
# Processing Record 32 of Set 6 | yerbogachen
# Processing Record 33 of Set 6 | solnechnyy
# Processing Record 34 of Set 6 | zanjan
# Processing Record 35 of Set 6 | uren
# Processing Record 36 of Set 6 | sibolga
# Processing Record 37 of Set 6 | skelleftea
# Processing Record 38 of Set 6 | san quintin
# Processing Record 39 of Set 6 | vostok
# Processing Record 40 of Set 6 | massakory
# Processing Record 41 of Set 6 | sovetskiy
# Processing Record 42 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 6 | ca mau
# Processing Record 44 of Set 6 | broome
# Processing Record 45 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 46 of Set 6 | karambakkudi
# Processing Record 47 of Set 6 | cassilandia
# Processing Record 48 of Set 6 | lerwick
# Processing Record 49 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 6 | hovd
# Processing Record 1 of Set 7 | sikonge
# Processing Record 2 of Set 7 | luderitz
# Processing Record 3 of Set 7 | narsaq
# Processing Record 4 of Set 7 | talaya
# Processing Record 5 of Set 7 | saint-pierre
# Processing Record 6 of Set 7 | rabak
# Processing Record 7 of Set 7 | chilca
# Processing Record 8 of Set 7 | severo-kurilsk
# Processing Record 9 of Set 7 | ulladulla
# Processing Record 10 of Set 7 | baracoa
# Processing Record 11 of Set 7 | boca do acre
# Processing Record 12 of Set 7 | mount gambier
# Processing Record 13 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 7 | birin
# Processing Record 15 of Set 7 | snezhnogorsk
# Processing Record 16 of Set 7 | gravdal
# Processing Record 17 of Set 7 | passo de camaragibe
# Processing Record 18 of Set 7 | hareid
# Processing Record 19 of Set 7 | shawnee
# Processing Record 20 of Set 7 | souillac
# Processing Record 21 of Set 7 | husavik
# Processing Record 22 of Set 7 | castro
# Processing Record 23 of Set 7 | new norfolk
# Processing Record 24 of Set 7 | warah
# Processing Record 25 of Set 7 | sorong
# Processing Record 26 of Set 7 | utkivka
# Processing Record 27 of Set 7 | suez
# Processing Record 28 of Set 7 | oksfjord
# Processing Record 29 of Set 7 | henties bay
# Processing Record 30 of Set 7 | kostomuksha
# Processing Record 31 of Set 7 | hobyo
# Processing Record 32 of Set 7 | saint-joseph
# Processing Record 33 of Set 7 | rawson
# Processing Record 34 of Set 7 | ibotirama
# Processing Record 35 of Set 7 | trairi
# Processing Record 36 of Set 7 | port lincoln
# Processing Record 37 of Set 7 | clyde river
# Processing Record 38 of Set 7 | wanning
# Processing Record 39 of Set 7 | tuy hoa
# Processing Record 40 of Set 7 | berdigestyakh
# Processing Record 41 of Set 7 | dehloran
# Processing Record 42 of Set 7 | brae
# Processing Record 43 of Set 7 | palu
# Processing Record 44 of Set 7 | kenai
# Processing Record 45 of Set 7 | kiruna
# Processing Record 46 of Set 7 | tulsipur
# Processing Record 47 of Set 7 | benavente
# Processing Record 48 of Set 7 | honningsvag
# Processing Record 49 of Set 7 | boo
# Processing Record 50 of Set 7 | sakaiminato
# Processing Record 1 of Set 8 | vila velha
# Processing Record 2 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 4 of Set 8 | saqqez
# Processing Record 5 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 8 | havelock
# Processing Record 7 of Set 8 | ziro
# Processing Record 8 of Set 8 | kota belud
# Processing Record 9 of Set 8 | hit
# Processing Record 10 of Set 8 | pogradec
# Processing Record 11 of Set 8 | miles city
# Processing Record 12 of Set 8 | chara
# Processing Record 13 of Set 8 | santa rosa
# Processing Record 14 of Set 8 | polson
# Processing Record 15 of Set 8 | bahia blanca
# Processing Record 16 of Set 8 | mumford
# Processing Record 17 of Set 8 | tibu
# Processing Record 18 of Set 8 | maracas
# Processing Record 19 of Set 8 | pemberton
# Processing Record 20 of Set 8 | bambanglipuro
# Processing Record 21 of Set 8 | dayong
# Processing Record 22 of Set 8 | porto novo
# Processing Record 23 of Set 8 | itoman
# Processing Record 24 of Set 8 | conde
# Processing Record 25 of Set 8 | tocopilla
# Processing Record 26 of Set 8 | esil
# Processing Record 27 of Set 8 | el tigre
# Processing Record 28 of Set 8 | vao
# Processing Record 29 of Set 8 | portland
# Processing Record 30 of Set 8 | srednekolymsk
# Processing Record 31 of Set 8 | bambous virieux
# Processing Record 32 of Set 8 | kihei
# Processing Record 33 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 8 | banjar
# Processing Record 35 of Set 8 | aripuana
# Processing Record 36 of Set 8 | coihaique
# Processing Record 37 of Set 8 | port keats
# Processing Record 38 of Set 8 | comodoro rivadavia
# Processing Record 39 of Set 8 | esmeraldas
# Processing Record 40 of Set 8 | bria
# Processing Record 41 of Set 8 | lavrentiya
# Processing Record 42 of Set 8 | toppenish
# Processing Record 43 of Set 8 | aksu
# Processing Record 44 of Set 8 | flinders
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | abu samrah
# Processing Record 47 of Set 8 | fort nelson
# Processing Record 48 of Set 8 | amalapuram
# Processing Record 49 of Set 8 | klaksvik
# Processing Record 50 of Set 8 | trelew
# Processing Record 1 of Set 9 | paamiut
# Processing Record 2 of Set 9 | lubyany
# Processing Record 3 of Set 9 | ingham
# Processing Record 4 of Set 9 | lubango
# Processing Record 5 of Set 9 | hokitika
# Processing Record 6 of Set 9 | manta
# Processing Record 7 of Set 9 | labuhan
# Processing Record 8 of Set 9 | mastic beach
# Processing Record 9 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 9 | wahiawa
# Processing Record 11 of Set 9 | marawi
# Processing Record 12 of Set 9 | bone
# Processing Record 13 of Set 9 | avera
# Processing Record 14 of Set 9 | lillesand
# Processing Record 15 of Set 9 | bac lieu
# Processing Record 16 of Set 9 | mnogovershinnyy
# Processing Record 17 of Set 9 | okahandja
# Processing Record 18 of Set 9 | ballarat
# Processing Record 19 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 20 of Set 9 | druzhnaya gorka
# Processing Record 21 of Set 9 | ust-nera
# Processing Record 22 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 23 of Set 9 | terrace
# Processing Record 24 of Set 9 | ogulin
# Processing Record 25 of Set 9 | manaus
# Processing Record 26 of Set 9 | mareeba
# Processing Record 27 of Set 9 | pouebo
# Processing Record 28 of Set 9 | merauke
# Processing Record 29 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 9 | shishou
# Processing Record 31 of Set 9 | darhan
# Processing Record 32 of Set 9 | viedma
# Processing Record 33 of Set 9 | marsh harbour
# Processing Record 34 of Set 9 | leh
# Processing Record 35 of Set 9 | los llanos de aridane
# Processing Record 36 of Set 9 | aswan
# Processing Record 37 of Set 9 | manavalakurichi
# Processing Record 38 of Set 9 | springbok
# Processing Record 39 of Set 9 | roald
# Processing Record 40 of Set 9 | tel aviv-yafo
# Processing Record 41 of Set 9 | mecca
# Processing Record 42 of Set 9 | kutum
# Processing Record 43 of Set 9 | suntar
# Processing Record 44 of Set 9 | chingirlau
# Processing Record 45 of Set 9 | katsuura
# Processing Record 46 of Set 9 | macklin
# Processing Record 47 of Set 9 | kaeo
# Processing Record 48 of Set 9 | sao filipe
# Processing Record 49 of Set 9 | airai
# Processing Record 50 of Set 9 | baependi
# Processing Record 1 of Set 10 | arlit
# Processing Record 2 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 10 | xining
# Processing Record 4 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 10 | lagoa
# Processing Record 6 of Set 10 | ayan
# Processing Record 7 of Set 10 | espinho
# Processing Record 8 of Set 10 | makhinjauri
# Processing Record 9 of Set 10 | andenes
# Processing Record 10 of Set 10 | leningradskiy
# Processing Record 11 of Set 10 | macusani
# Processing Record 12 of Set 10 | atherton
# Processing Record 13 of Set 10 | faanui
# Processing Record 14 of Set 10 | cortes
# Processing Record 15 of Set 10 | bilibino
# Processing Record 16 of Set 10 | bintulu
# Processing Record 17 of Set 10 | milharado
# Processing Record 18 of Set 10 | sala
# Processing Record 19 of Set 10 | moranbah
# Processing Record 20 of Set 10 | cedar lake
# Processing Record 21 of Set 10 | vila franca do campo
# Processing Record 22 of Set 10 | mithi
# Processing Record 23 of Set 10 | ambrolauri
# Processing Record 24 of Set 10 | bam
# Processing Record 25 of Set 10 | domoni
# Processing Record 26 of Set 10 | hamilton
# Processing Record 27 of Set 10 | bilma
# Processing Record 28 of Set 10 | le port
# Processing Record 29 of Set 10 | talavera de la reina
# Processing Record 30 of Set 10 | port hedland
# Processing Record 31 of Set 10 | nishihara
# Processing Record 32 of Set 10 | buraydah
# Processing Record 33 of Set 10 | zaraza
# Processing Record 34 of Set 10 | gander
# Processing Record 35 of Set 10 | fomboni
# Processing Record 36 of Set 10 | guapiles
# Processing Record 37 of Set 10 | sovetskaya gavan
# Processing Record 38 of Set 10 | hattiesburg
# Processing Record 39 of Set 10 | qeshm
# Processing Record 40 of Set 10 | longhua
# Processing Record 41 of Set 10 | pyaozerskiy
# Processing Record 42 of Set 10 | dakar
# Processing Record 43 of Set 10 | omboue
# Processing Record 44 of Set 10 | anadyr
# Processing Record 45 of Set 10 | swan hill
# Processing Record 46 of Set 10 | lucapa
# Processing Record 47 of Set 10 | sunrise manor
# Processing Record 48 of Set 10 | shumikha
# Processing Record 49 of Set 10 | amapa
# Processing Record 50 of Set 10 | sam chuk
# Processing Record 1 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 11 | mahanoro
# Processing Record 3 of Set 11 | inhambane
# Processing Record 4 of Set 11 | gracac
# Processing Record 5 of Set 11 | tarko-sale
# Processing Record 6 of Set 11 | tubmanburg
# Processing Record 7 of Set 11 | bihoro
# Processing Record 8 of Set 11 | vestmanna
# Processing Record 9 of Set 11 | pomabamba
# Processing Record 10 of Set 11 | san ramon
# Processing Record 11 of Set 11 | pirovskoye
# Processing Record 12 of Set 11 | raiwala
# Processing Record 13 of Set 11 | sonoma
# Processing Record 14 of Set 11 | darya khan mari
# City not found. Skipping...
# Processing Record 15 of Set 11 | acapulco
# Processing Record 16 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 11 | sao miguel do araguaia
# Processing Record 18 of Set 11 | ginda
# Processing Record 19 of Set 11 | linshu
# City not found. Skipping...
# Processing Record 20 of Set 11 | zaysan
# Processing Record 21 of Set 11 | murgab
# Processing Record 22 of Set 11 | la ronge
# Processing Record 23 of Set 11 | bundaberg
# Processing Record 24 of Set 11 | sayyan
# Processing Record 25 of Set 11 | sao joao da barra
# Processing Record 26 of Set 11 | yichang
# Processing Record 27 of Set 11 | chumikan
# Processing Record 28 of Set 11 | makakilo city
# Processing Record 29 of Set 11 | ponta delgada
# Processing Record 30 of Set 11 | melendugno
# Processing Record 31 of Set 11 | kailua
# Processing Record 32 of Set 11 | timizart
# Processing Record 33 of Set 11 | auki
# Processing Record 34 of Set 11 | sioux lookout
# Processing Record 35 of Set 11 | gurun
# Processing Record 36 of Set 11 | victor harbor
# Processing Record 37 of Set 11 | fianarantsoa
# Processing Record 38 of Set 11 | rumoi
# Processing Record 39 of Set 11 | kurchum
# Processing Record 40 of Set 11 | gornopravdinsk
# Processing Record 41 of Set 11 | tual
# Processing Record 42 of Set 11 | andros town
# Processing Record 43 of Set 11 | gunnedah
# Processing Record 44 of Set 11 | monrovia
# Processing Record 45 of Set 11 | itarema
# Processing Record 46 of Set 11 | nara
# Processing Record 47 of Set 11 | hatillo
# Processing Record 48 of Set 11 | marienburg
# Processing Record 49 of Set 11 | gat
# Processing Record 50 of Set 11 | baie-comeau
# Processing Record 1 of Set 12 | truth or consequences
# Processing Record 2 of Set 12 | mahina
# Processing Record 3 of Set 12 | kayerkan
# Processing Record 4 of Set 12 | den helder
# Processing Record 5 of Set 12 | ajaccio
# Processing Record 6 of Set 12 | beloha
# Processing Record 7 of Set 12 | pimenta bueno
# Processing Record 8 of Set 12 | humberto de campos
# Processing Record 9 of Set 12 | mulchen
# Processing Record 10 of Set 12 | syracuse
# Processing Record 11 of Set 12 | sobolevo
# Processing Record 12 of Set 12 | balkhash
# Processing Record 13 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 12 | uruzgan
# Processing Record 15 of Set 12 | nabire
# Processing Record 16 of Set 12 | barquisimeto
# Processing Record 17 of Set 12 | malanville
# Processing Record 18 of Set 12 | mezen
# Processing Record 19 of Set 12 | belyy yar
# Processing Record 20 of Set 12 | paragominas
# Processing Record 21 of Set 12 | mangrol
# Processing Record 22 of Set 12 | axim
# Processing Record 23 of Set 12 | fallon
# Processing Record 24 of Set 12 | tecoanapa
# Processing Record 25 of Set 12 | pitimbu
# Processing Record 26 of Set 12 | ballina
# Processing Record 27 of Set 12 | puerto del rosario
# Processing Record 28 of Set 12 | sfantu gheorghe
# Processing Record 29 of Set 12 | villa carlos paz
# Processing Record 30 of Set 12 | mogadishu
# Processing Record 31 of Set 12 | constitucion
# Processing Record 32 of Set 12 | maravilha
# Processing Record 33 of Set 12 | igarka
# Processing Record 34 of Set 12 | keti bandar
# Processing Record 35 of Set 12 | la asuncion
# Processing Record 36 of Set 12 | killybegs
# Processing Record 37 of Set 12 | nyurba
# Processing Record 38 of Set 12 | parsabad
# Processing Record 39 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 12 | fairbanks
# Processing Record 41 of Set 12 | athabasca
# Processing Record 42 of Set 12 | eyl
# Processing Record 43 of Set 12 | alma
# Processing Record 44 of Set 12 | sinegorsk
# Processing Record 45 of Set 12 | saint-augustin
# Processing Record 46 of Set 12 | nuevitas
# Processing Record 47 of Set 12 | antalaha
# Processing Record 48 of Set 12 | asau
# Processing Record 49 of Set 12 | alamosa
# Processing Record 50 of Set 12 | lokosovo
# Processing Record 1 of Set 13 | guiratinga
# Processing Record 2 of Set 13 | klin
# Processing Record 3 of Set 13 | erdemli
# Processing Record 4 of Set 13 | deogarh
# Processing Record 5 of Set 13 | pascagoula
# Processing Record 6 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 7 of Set 13 | tautira
# Processing Record 8 of Set 13 | baraboo
# Processing Record 9 of Set 13 | huarmey
# Processing Record 10 of Set 13 | baykit
# Processing Record 11 of Set 13 | kiunga
# Processing Record 12 of Set 13 | xiaoweizhai
# Processing Record 13 of Set 13 | adrar
# Processing Record 14 of Set 13 | yamada
# Processing Record 15 of Set 13 | sulangan
# Processing Record 16 of Set 13 | halifax
# Processing Record 17 of Set 13 | samarai
# Processing Record 18 of Set 13 | egvekinot
# Processing Record 19 of Set 13 | ushirombo
# Processing Record 20 of Set 13 | pangnirtung
# Processing Record 21 of Set 13 | helena
# Processing Record 22 of Set 13 | houma
# Processing Record 23 of Set 13 | paita
# Processing Record 24 of Set 13 | tigre
# Processing Record 25 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 26 of Set 13 | saurimo
# Processing Record 27 of Set 13 | hun
# Processing Record 28 of Set 13 | nago
# Processing Record 29 of Set 13 | port hardy
# Processing Record 30 of Set 13 | adre
# Processing Record 31 of Set 13 | salalah
# Processing Record 32 of Set 13 | san carlos de bariloche
# Processing Record 33 of Set 13 | khani
# Processing Record 34 of Set 13 | tabory
# Processing Record 35 of Set 13 | waipawa
# Processing Record 36 of Set 13 | nakhon phanom
# Processing Record 37 of Set 13 | shingu
# Processing Record 38 of Set 13 | oktyabrskoye
# Processing Record 39 of Set 13 | huanren
# Processing Record 40 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 41 of Set 13 | mitsamiouli
# Processing Record 42 of Set 13 | surt
# Processing Record 43 of Set 13 | elk city
# Processing Record 44 of Set 13 | zhoucheng
# Processing Record 45 of Set 13 | brattvag
# Processing Record 46 of Set 13 | borgarnes
# Processing Record 47 of Set 13 | belaya gora
# Processing Record 48 of Set 13 | dossor
# Processing Record 49 of Set 13 | xinzhou
# Processing Record 50 of Set 13 | warwick
# Processing Record 1 of Set 14 | la macarena
# Processing Record 2 of Set 14 | kitimat
# Processing Record 3 of Set 14 | banda aceh
# Processing Record 4 of Set 14 | umm kaddadah
# Processing Record 5 of Set 14 | isangel
# Processing Record 6 of Set 14 | lazaro cardenas
# Processing Record 7 of Set 14 | potsdam
# Processing Record 8 of Set 14 | narasannapeta
# Processing Record 9 of Set 14 | sakakah
# Processing Record 10 of Set 14 | aykino
# Processing Record 11 of Set 14 | socorro
# Processing Record 12 of Set 14 | lumphat
# Processing Record 13 of Set 14 | rundu
# Processing Record 14 of Set 14 | baiquan
# Processing Record 15 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 14 | haines junction
# Processing Record 17 of Set 14 | yangjiang
# Processing Record 18 of Set 14 | mount isa
# Processing Record 19 of Set 14 | tazovskiy
# Processing Record 20 of Set 14 | kaura namoda
# Processing Record 21 of Set 14 | mpulungu
# Processing Record 22 of Set 14 | magrath
# Processing Record 23 of Set 14 | sokoto
# Processing Record 24 of Set 14 | kangaatsiaq
# Processing Record 25 of Set 14 | jimeta
# Processing Record 26 of Set 14 | blackfoot
# Processing Record 27 of Set 14 | manokwari
# Processing Record 28 of Set 14 | aljezur
# Processing Record 29 of Set 14 | inta
# Processing Record 30 of Set 14 | lasa
# Processing Record 31 of Set 14 | bajil
# Processing Record 32 of Set 14 | shafter
# Processing Record 33 of Set 14 | yetkul
# Processing Record 34 of Set 14 | christchurch
# Processing Record 35 of Set 14 | bati
# Processing Record 36 of Set 14 | panaba
# Processing Record 37 of Set 14 | przeworsk
# Processing Record 38 of Set 14 | cayenne
# Processing Record 39 of Set 14 | riyadh
# Processing Record 40 of Set 14 | khasan
# Processing Record 41 of Set 14 | orleans
# Processing Record 42 of Set 14 | isabela
# Processing Record 43 of Set 14 | moose factory
# Processing Record 44 of Set 14 | simao
# Processing Record 45 of Set 14 | segou
# Processing Record 46 of Set 14 | esfarayen
# Processing Record 47 of Set 14 | nacunday
# City not found. Skipping...
# Processing Record 48 of Set 14 | chase
# Processing Record 49 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 14 | byron bay
# Processing Record 1 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 2 of Set 15 | aykhal
# Processing Record 3 of Set 15 | alegrete
# Processing Record 4 of Set 15 | nelson bay
# Processing Record 5 of Set 15 | uyemskiy
# Processing Record 6 of Set 15 | bukama
# Processing Record 7 of Set 15 | kudahuvadhoo
# Processing Record 8 of Set 15 | alihe
# Processing Record 9 of Set 15 | kolvereid
# Processing Record 10 of Set 15 | havre-saint-pierre
# Processing Record 11 of Set 15 | bodden town
# Processing Record 12 of Set 15 | mahibadhoo
# Processing Record 13 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 14 of Set 15 | college
# Processing Record 15 of Set 15 | laredo
# Processing Record 16 of Set 15 | baruun-urt
# Processing Record 17 of Set 15 | nahavand
# Processing Record 18 of Set 15 | tommot
# Processing Record 19 of Set 15 | ursulo galvan
# Processing Record 20 of Set 15 | mkokotoni
# Processing Record 21 of Set 15 | odda
# Processing Record 22 of Set 15 | anshun
# Processing Record 23 of Set 15 | kingston
# Processing Record 24 of Set 15 | quillota
# Processing Record 25 of Set 15 | nampa
# Processing Record 26 of Set 15 | rabo de peixe
# Processing Record 27 of Set 15 | primorsk
# Processing Record 28 of Set 15 | matamoros
# Processing Record 29 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 30 of Set 15 | borzna
# Processing Record 31 of Set 15 | srivardhan
# Processing Record 32 of Set 15 | lata
# Processing Record 33 of Set 15 | tessalit
# Processing Record 34 of Set 15 | dali
# Processing Record 35 of Set 15 | dhidhdhoo
# Processing Record 36 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 15 | longonjo
# Processing Record 38 of Set 15 | atar
# Processing Record 39 of Set 15 | bay roberts
# Processing Record 40 of Set 15 | richards bay
# Processing Record 41 of Set 15 | mulege
# Processing Record 42 of Set 15 | tiznit
# Processing Record 43 of Set 15 | malindi
# Processing Record 44 of Set 15 | charleston
# Processing Record 45 of Set 15 | ixtapa
# Processing Record 46 of Set 15 | gaur
# Processing Record 47 of Set 15 | bonthe
# Processing Record 48 of Set 15 | barcelos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Confirm number of cities
len(city_data)
# Out:
# 698

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bartica   6.4000  -58.6167     79.12        96          98
# 1  Half Moon Bay  37.4636 -122.4286     78.58        71           0
# 2         Langsa   4.4683   97.9683     78.44        84          43
# 3      Saskylakh  71.9167  114.0833     54.07        92         100
# 4      Cape Town -33.9258   18.4232     57.11        91          75
# 5       Victoria  22.2855  114.1577     85.24        83         100
# 6           Hilo  19.7297 -155.0900     88.29        82          75
# 7       Maragogi  -9.0122  -35.2225     73.47        80           3
# 8           Poum -20.2333  164.0167     70.86        64          17
# 9      Katherine -14.4667  132.2667     84.52        24           0
#
#    Wind Speed Country Current Description
# 0        3.44      GY     overcast clouds
# 1       17.27      US           clear sky
# 2        1.43      ID    scattered clouds
# 3        5.26      RU          light rain
# 4       16.11      ZA          light rain
# 5       18.99      HK     overcast clouds
# 6        9.22      US       broken clouds
# 7        5.37      BR           clear sky
# 8       23.20      NC          few clouds
# 9        9.22      AU           clear sky

# %%
# Reorder the columns as City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, and Current Description
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bartica      GY   6.4000  -58.6167     79.12        96          98
# 1  Half Moon Bay      US  37.4636 -122.4286     78.58        71           0
# 2         Langsa      ID   4.4683   97.9683     78.44        84          43
# 3      Saskylakh      RU  71.9167  114.0833     54.07        92         100
# 4      Cape Town      ZA -33.9258   18.4232     57.11        91          75
# 5       Victoria      HK  22.2855  114.1577     85.24        83         100
# 6           Hilo      US  19.7297 -155.0900     88.29        82          75
# 7       Maragogi      BR  -9.0122  -35.2225     73.47        80           3
# 8           Poum      NC -20.2333  164.0167     70.86        64          17
# 9      Katherine      AU -14.4667  132.2667     84.52        24           0
#
#    Wind Speed Current Description
# 0        3.44     overcast clouds
# 1       17.27           clear sky
# 2        1.43    scattered clouds
# 3        5.26          light rain
# 4       16.11          light rain
# 5       18.99     overcast clouds
# 6        9.22       broken clouds
# 7        5.37           clear sky
# 8       23.20          few clouds
# 9        9.22           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
